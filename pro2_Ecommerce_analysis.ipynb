# %% [markdown]
# Ecommerce Analysis Project

# %%
import numpy as np 
import pandas as pd

# %%
# %pip install openpyxl
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
df = pd.read_excel("Ecommerce_Unclean_Project.xlsx")

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 524 entries, 0 to 523
# Data columns (total 15 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Order_ID       524 non-null    str
#  1   Order_Date     524 non-null    str
#  2   Customer_Name  524 non-null    str
#  3   Email          524 non-null    str
#  4   Phone          502 non-null    float64
#  5   City           524 non-null    str
#  6   State          524 non-null    str
#  7   Product        524 non-null    str
#  8   Category       524 non-null    str
#  9   Qty            457 non-null    float64
#  10  Unit_Price     471 non-null    float64
#  11  Discount       455 non-null    object
#  12  Payment_Mode   524 non-null    str
#  13  Order_Status   524 non-null    str
#  14  Delivery_Date  503 non-null    str
# dtypes: float64(3), object(1), str(11)
# memory usage: 61.5+ KB

# %%
df.head()
# Out:
#   Order_ID  Order_Date Customer_Name              Email         Phone  \
# 0  ORD1002  30-06-2025          Neha   neha82@gmail.com  9.829008e+09
# 1  ORD1003  03-02-2025         Rohit  rohit45@gmail.com  9.280491e+09
# 2  ORD1004  06-05-2025          Amit    amit6@gmail.com  9.943311e+09
# 3  ORD1005  20-01-2025         Vikas  vikas51@gmail.com  9.495120e+09
# 4  ORD1006  02-04-2025         Rohit  rohit71@gmail.com  9.237332e+09
#
#         City        State Product     Category  Qty  Unit_Price Discount  \
# 0      Delhi        Delhi   Chair    Furniture  4.0      1999.0      NaN
# 1       Pune  Maharashtra   Watch      Fashion  5.0      4999.0       20
# 2     Jaipur    Rajasthan   Mouse  Electronics  3.0      1999.0        5
# 3  Bengaluru    Karnataka  Laptop  Electronics  NaN         NaN       15
# 4       Pune  Maharashtra  Bottle         Home  NaN      1999.0
#
#   Payment_Mode Order_Status Delivery_Date
# 0          UPI      Pending    03-07-2025
# ...

# %%
# statstics
df.describe()
# Out:
#               Phone         Qty   Unit_Price
# count  5.020000e+02  457.000000   471.000000
# mean   9.544725e+09    2.800875  3168.639066
# std    2.636920e+08    1.963974  2969.682209
# min    9.104441e+09   -1.000000   499.000000
# 25%    9.315673e+09    1.000000   999.000000
# 50%    9.533562e+09    3.000000  1999.000000
# 75%    9.792574e+09    5.000000  4999.000000
# max    9.999074e+09    5.000000  9999.000000

# %%
# data set shape
df.shape
# Out:
# (524, 15)

# %%
# step 4 check missing 
df.isnull().sum()
# Out:
# Order_ID          0
# Order_Date        0
# Customer_Name     0
# Email             0
# Phone            22
# City              0
# State             0
# Product           0
# Category          0
# Qty              67
# Unit_Price       53
# Discount         69
# Payment_Mode      0
# Order_Status      0
# Delivery_Date    21
# dtype: int64

# %%
# step 5 check duplicate records
df.duplicated().sum()
# Out:
# np.int64(11)

# %%
# Remoce duplicate records
df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
# Replace invalid values
# Replace comman invalid values with NaN
df.replace(['N/A', 'NULL',''],np.nan,inplace=True)
df.sample(7)
# Out:
#     Order_ID  Order_Date Customer_Name              Email         Phone  \
# 152  ORD1154  24-04-2025         Priya  priya58@gmail.com           NaN
# 117  ORD1119  12-02-2025         Rohit  rohit97@gmail.com  9.739414e+09
# 314  ORD1316  14-02-2025          Amit   amit95@gmail.com  9.399341e+09
# 431  ORD1433  16-04-2025         Sneha  sneha19@gmail.com  9.818264e+09
# 407  ORD1409  06-02-2025         Priya   priya1@gmail.com  9.526868e+09
# 187  ORD1189  2025/04/30        neha     neha84@gmail.com  9.104441e+09
# 40   ORD1042  13-01-2025         Rahul  rahul66@gmail.com  9.792041e+09
#
#           City        State Product     Category  Qty  Unit_Price Discount  \
# 152       Pune  Maharashtra   Shoes      Fashion  5.0      2599.0      NaN
# 117  Bengaluru    Karnataka  Laptop  Electronics  5.0      1999.0
# 314     Jaipur    Rajasthan  Bottle         Home  3.0         NaN       15
# 431     Jaipur    Rajasthan   Shoes      Fashion  5.0       499.0       15
# ...

# %%
# step 7 remove extra spaces
df  = df.apply(lambda x : x.str.strip() if x.dtype == 'object' else x)

# %%
# step 8 Standardize text format
# convert text into proper format
df['Customer_Name'] = df['Customer_Name'].str.title()
df['City'] = df['City'].str.title()
df['State'] = df['State'].str.title()

# %%
# step 9 valid email address
# keep only valid email address
df = df[df['Email'].str.contains('@',na=False)]

# %%
# step 10 Convert Date Format
df['Order_Date'] = pd.to_datetime(df['Order_Date'], errors='coerce') # NAT
df['Delivery_Date'] = pd.to_datetime(df['Delivery_Date'], errors='coerce')
# Out:
# C:\Users\Mohd Shamsher\AppData\Local\Temp\ipykernel_6488\604734311.py:2: UserWarning: Parsing dates in %d-%m-%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   df['Order_Date'] = pd.to_datetime(df['Order_Date'], errors='coerce') # NAT

# %%
# 11 convert numeric columns 
cols = ['Qty','Unit_Price','Discount']
for c in cols:
    df[c] = pd.to_numeric(df[c], errors='coerce')

# %%
# step 12 Remove invalid quantity
# reomve records having negative or zero quantity
df = df[df['Qty']>0]

# %%
# step 13 fill missing values
df['Discount'] = df['Discount'].fillna(0)
df['Phone'] = df['Phone'].fillna('Unknown')
df['Delivery_Date'] = df['Delivery_Date'].fillna(df['Order_Date'])

# %%
# step 14 Feature Engineering
df['Sales'] = df['Qty']* df['Unit_Price']
df.head()
# Out:
#   Order_ID Order_Date Customer_Name              Email         Phone     City  \
# 0  ORD1002 2025-06-30          Neha   neha82@gmail.com  9829008196.0    Delhi
# 1  ORD1003 2025-02-03         Rohit  rohit45@gmail.com  9280491167.0     Pune
# 2  ORD1004 2025-05-06          Amit    amit6@gmail.com  9943310925.0   Jaipur
# 5  ORD1007 2025-02-10         Rahul  rahul82@gmail.com  9517780193.0   Mumbai
# 6  ORD1008 2025-02-17         Rahul  rahul71@gmail.com  9789375429.0  Lucknow
#
#          State Product     Category  Qty  Unit_Price  Discount Payment_Mode  \
# 0        Delhi   Chair    Furniture  4.0      1999.0       0.0          UPI
# 1  Maharashtra   Watch      Fashion  5.0      4999.0       0.0         Card
# 2    Rajasthan   Mouse  Electronics  3.0      1999.0       0.0          COD
# 5  Maharashtra   Mouse  Electronics  3.0       499.0       0.0       Wallet
# 6           Up   Mouse  Electronics  4.0      9999.0       0.0         Card
#
#   Order_Status Delivery_Date    Sales
# ...

# %%
# Net Amount 
df['Net_Amount']= (df['Sales'] - df['Discount']/10)
df.head()
# Out:
#   Order_ID Order_Date Customer_Name              Email         Phone     City  \
# 0  ORD1002 2025-06-30          Neha   neha82@gmail.com  9829008196.0    Delhi
# 1  ORD1003 2025-02-03         Rohit  rohit45@gmail.com  9280491167.0     Pune
# 2  ORD1004 2025-05-06          Amit    amit6@gmail.com  9943310925.0   Jaipur
# 5  ORD1007 2025-02-10         Rahul  rahul82@gmail.com  9517780193.0   Mumbai
# 6  ORD1008 2025-02-17         Rahul  rahul71@gmail.com  9789375429.0  Lucknow
#
#          State Product     Category  Qty  Unit_Price  Discount Payment_Mode  \
# 0        Delhi   Chair    Furniture  4.0      1999.0       0.0          UPI
# 1  Maharashtra   Watch      Fashion  5.0      4999.0       0.0         Card
# 2    Rajasthan   Mouse  Electronics  3.0      1999.0       0.0          COD
# 5  Maharashtra   Mouse  Electronics  3.0       499.0       0.0       Wallet
# 6           Up   Mouse  Electronics  4.0      9999.0       0.0         Card
#
# ...

# %%
# Profit (Example 20%)
df['Profit'] = df['Net_Amount']*0.02
df.head()
# Out:
#   Order_ID Order_Date Customer_Name              Email         Phone     City  \
# 0  ORD1002 2025-06-30          Neha   neha82@gmail.com  9829008196.0    Delhi
# 1  ORD1003 2025-02-03         Rohit  rohit45@gmail.com  9280491167.0     Pune
# 2  ORD1004 2025-05-06          Amit    amit6@gmail.com  9943310925.0   Jaipur
# 5  ORD1007 2025-02-10         Rahul  rahul82@gmail.com  9517780193.0   Mumbai
# 6  ORD1008 2025-02-17         Rahul  rahul71@gmail.com  9789375429.0  Lucknow
#
#          State Product     Category  Qty  Unit_Price  Discount Payment_Mode  \
# 0        Delhi   Chair    Furniture  4.0      1999.0       0.0          UPI
# 1  Maharashtra   Watch      Fashion  5.0      4999.0       0.0         Card
# 2    Rajasthan   Mouse  Electronics  3.0      1999.0       0.0          COD
# 5  Maharashtra   Mouse  Electronics  3.0       499.0       0.0       Wallet
# 6           Up   Mouse  Electronics  4.0      9999.0       0.0         Card
#
# ...

# %%
# order month
df['month']  = df['Order_Date'].dt.month_name()

# %%
# order year
df['Year'] = df['Order_Date'].dt.year
df.head()
# Out:
#   Order_ID Order_Date Customer_Name              Email         Phone     City  \
# 0  ORD1002 2025-06-30          Neha   neha82@gmail.com  9829008196.0    Delhi
# 1  ORD1003 2025-02-03         Rohit  rohit45@gmail.com  9280491167.0     Pune
# 2  ORD1004 2025-05-06          Amit    amit6@gmail.com  9943310925.0   Jaipur
# 5  ORD1007 2025-02-10         Rahul  rahul82@gmail.com  9517780193.0   Mumbai
# 6  ORD1008 2025-02-17         Rahul  rahul71@gmail.com  9789375429.0  Lucknow
#
#          State Product     Category  Qty  Unit_Price  Discount Payment_Mode  \
# 0        Delhi   Chair    Furniture  4.0      1999.0       0.0          UPI
# 1  Maharashtra   Watch      Fashion  5.0      4999.0       0.0         Card
# 2    Rajasthan   Mouse  Electronics  3.0      1999.0       0.0          COD
# 5  Maharashtra   Mouse  Electronics  3.0       499.0       0.0       Wallet
# 6           Up   Mouse  Electronics  4.0      9999.0       0.0         Card
#
# ...

# %%
df['Weekday'] = df['Order_Date'].dt.day_name()
df.head()
# Out:
#   Order_ID Order_Date Customer_Name              Email         Phone     City  \
# 0  ORD1002 2025-06-30          Neha   neha82@gmail.com  9829008196.0    Delhi
# 1  ORD1003 2025-02-03         Rohit  rohit45@gmail.com  9280491167.0     Pune
# 2  ORD1004 2025-05-06          Amit    amit6@gmail.com  9943310925.0   Jaipur
# 5  ORD1007 2025-02-10         Rahul  rahul82@gmail.com  9517780193.0   Mumbai
# 6  ORD1008 2025-02-17         Rahul  rahul71@gmail.com  9789375429.0  Lucknow
#
#          State Product     Category  Qty  ...  Discount  Payment_Mode  \
# 0        Delhi   Chair    Furniture  4.0  ...       0.0           UPI
# 1  Maharashtra   Watch      Fashion  5.0  ...       0.0          Card
# 2    Rajasthan   Mouse  Electronics  3.0  ...       0.0           COD
# 5  Maharashtra   Mouse  Electronics  3.0  ...       0.0        Wallet
# 6           Up   Mouse  Electronics  4.0  ...       0.0          Card
#
# ...

# %%
# step 15 final visualization
df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 380 entries, 0 to 523
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Order_ID       380 non-null    str
#  1   Order_Date     333 non-null    datetime64[us]
#  2   Customer_Name  380 non-null    str
#  3   Email          380 non-null    str
#  4   Phone          380 non-null    object
#  5   City           380 non-null    str
#  6   State          380 non-null    str
#  7   Product        380 non-null    str
#  8   Category       380 non-null    str
#  9   Qty            380 non-null    float64
#  10  Unit_Price     343 non-null    float64
#  11  Discount       380 non-null    float64
#  12  Payment_Mode   380 non-null    str
#  13  Order_Status   380 non-null    str
#  14  Delivery_Date  348 non-null    datetime64[us]
#  15  Sales          343 non-null    float64
#  16  Net_Amount     343 non-null    float64
#  17  Profit         343 non-null    float64
# ...

# %%
df.isnull().sum()
# Out:
# Order_ID          0
# Order_Date       47
# Customer_Name     0
# Email             0
# Phone             0
# City              0
# State             0
# Product           0
# Category          0
# Qty               0
# Unit_Price       37
# Discount          0
# Payment_Mode      0
# Order_Status      0
# Delivery_Date    32
# Sales            37
# Net_Amount       37
# Profit           37
# month            47
# Year             47
# Weekday          47
# dtype: int64

# %%
df.describe()
# Out:
#                        Order_Date         Qty   Unit_Price  Discount  \
# count                         333  380.000000   343.000000     380.0
# mean   2025-04-02 17:35:08.108108    3.328947  3252.352770       0.0
# min           2025-01-01 00:00:00    1.000000   499.000000       0.0
# 25%           2025-02-14 00:00:00    2.000000   999.000000       0.0
# 50%           2025-04-05 00:00:00    3.000000  1999.000000       0.0
# 75%           2025-05-16 00:00:00    5.000000  4999.000000       0.0
# max           2025-06-30 00:00:00    5.000000  9999.000000       0.0
# std                           NaN    1.458196  3026.092014       0.0
#
#                     Delivery_Date         Sales    Net_Amount      Profit  \
# count                         348    343.000000    343.000000  343.000000
# mean   2025-05-01 04:12:24.827586  11103.664723  11103.664723  222.073294
# min           2025-01-02 00:00:00    499.000000    499.000000    9.980000
# ...

# %%
# step 16 Export clean data
df.to_csv('Clean_Ecommerce_data.csv', index=False)

# %%
# %pip install SQLAlchemy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install PyMySQL
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# done installation

# %%
# step 17 import data into mysql
from sqlalchemy import create_engine

engine = create_engine('mysql+pymysql://root:root@localhost/ecommerce')

# %%
# export dataframe to mysql
from sqlalchemy import text

with engine.connect() as conn:
    result = conn.execute(text("SHOW TABLES"))
    print(result.fetchall())
# Out:
# [('orders',)]

# %%
df.shape
